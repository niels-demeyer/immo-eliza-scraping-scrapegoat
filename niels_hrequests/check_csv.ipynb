# %%
import pandas as pd

# Load the CSV file as a pandas DataFrame with 'latin1' encoding
df = pd.read_csv("result.csv", encoding="latin1")

# Now df is a DataFrame, and you can use pandas methods on it.

# %%
# Set the options
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Now when you display a DataFrame, it will show all rows and columns
df
# Out:
#          id  cluster  customers_0_id customers_0_type  \
# 0  11094262      NaN         2506159           AGENCY
#
#                        customers_0_email  \
# 0  cdproper_bruxelles@importfrommedia.be
#
#                                                customers_0_logoUrl  \
# 0  https://static.immoweb.be/logos/2506159.gif?cache=2024001601857
#
#    customers_0_phoneNumber customers_0_mobileNumber customers_0_name  \
# 0                      NaN         +32 477 42 43 04    CD Properties
#
#    customers_0_website customers_0_location_country  \
# 0                  NaN                      Belgium
#
#    customers_0_location_region customers_0_location_province  \
# 0                          NaN                      Brussels
#
#   customers_0_location_district customers_0_location_locality  \
# 0                      Brussels                     Bruxelles
#
#    customers_0_location_postalCode customers_0_location_street  \
# 0                             1060          AVENUE BRUGMANN 16
#
#    customers_0_location_number  customers_0_location_box  \
# 0                          NaN                       NaN
#
#    customers_0_location_propertyName  customers_0_location_floor  \
# 0                                NaN                         NaN
#
#    customers_0_location_latitude  customers_0_location_longitude  \
# 0                      50.821796                         4.35342
#
#    customers_0_location_distance  customers_0_location_approximated  \
# 0                            NaN                                NaN
#
#    customers_0_location_regionCode  customers_0_location_type  \
# 0                              NaN                        NaN
#
#    customers_0_location_hasSeaView  customers_0_location_pointsOfInterest  \
# 0                              NaN                                    NaN
#
#    customers_0_location_placeName  customers_0_ipiNo  customers_0_isOwner  \
# 0                             NaN             507885                 True
#
#   customers_0_contactHoursMobile customers_0_contactHoursLandline  \
# 0                        anytime                          anytime
#
#    customers_0_salesRepresentative  customers_0_features_page404  \
# 0                              NaN                          True
#
#    customers_0_features_investorFlag  customers_0_features_relatedClassifieds  \
# 0                              False                                     True
#
#    customers_0_features_leafletsCTA  customers_0_features_leadQualification  \
# 0                             False                                    True
#
#    customers_0_features_recommendation  premiumProjectPage_medias  \
# 0                                 True                        NaN
#
#    premiumProjectPage_options  premiumProjectPage_promoter  \
# 0                         NaN                          NaN
#
#    premiumProjectPage_tabs  flags_isPublicSale  flags_isNewClassified  \
# 0                      NaN               False                  False
#
#    flags_isNewPrice  flags_isInvestmentProject  flags_isNewlyBuilt  \
# 0             False                      False               False
#
#    flags_isNotarySale  flags_isLifeAnnuitySale  flags_adQuality  flags_date  \
# 0                 NaN                    False              NaN         NaN
#
#    flags_priceSqm  flags_price  flags_default  flags_isSoldOrRented  \
# 0             NaN          NaN            NaN                 False
#
#    flags_isLowEnergy  flags_percentSold  flags_isPassiveHouse  \
# 0                NaN                NaN                   NaN
#
#    flags_isNewRealEstateProject  flags_isAnInteractiveSale  \
# 0                         False                        NaN
#
#    flags_isUnderOption  \
# 0                False
#
#                                                               media_pictures_0_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_1.gif?cache=20240125052905
#
#                                                                media_pictures_0_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_1.jpg?cache=20240125052905
#
#                                                               media_pictures_0_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_1.jpg?cache=20240125052905
#
#    media_pictures_0_isVertical  \
# 0                        False
#
#                                                               media_pictures_1_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_2.gif?cache=20240125052905
#
#                                                                media_pictures_1_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_2.jpg?cache=20240125052905
#
#                                                               media_pictures_1_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_2.jpg?cache=20240125052905
#
#    media_pictures_1_isVertical  \
# 0                        False
#
#                                                               media_pictures_2_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_3.gif?cache=20240125052905
#
#                                                                media_pictures_2_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_3.jpg?cache=20240125052905
#
#                                                               media_pictures_2_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_3.jpg?cache=20240125052905
#
#    media_pictures_2_isVertical  \
# 0                        False
#
#                                                               media_pictures_3_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_4.gif?cache=20240125052905
#
#                                                                media_pictures_3_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_4.jpg?cache=20240125052905
#
#                                                               media_pictures_3_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_4.jpg?cache=20240125052905
#
#    media_pictures_3_isVertical  \
# 0                        False
#
#                                                               media_pictures_4_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_5.gif?cache=20240125052905
#
#                                                                media_pictures_4_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_5.jpg?cache=20240125052905
#
#                                                               media_pictures_4_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_5.jpg?cache=20240125052905
#
#    media_pictures_4_isVertical  \
# 0                        False
#
#                                                               media_pictures_5_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_6.gif?cache=20240125052905
#
#                                                                media_pictures_5_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_6.jpg?cache=20240125052905
#
#                                                               media_pictures_5_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_6.jpg?cache=20240125052905
#
#    media_pictures_5_isVertical  \
# 0                        False
#
#                                                               media_pictures_6_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_7.gif?cache=20240125052905
#
#                                                                media_pictures_6_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_7.jpg?cache=20240125052905
#
#                                                               media_pictures_6_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_7.jpg?cache=20240125052905
#
#    media_pictures_6_isVertical  \
# 0                        False
#
#                                                               media_pictures_7_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_8.gif?cache=20240125052905
#
#                                                                media_pictures_7_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_8.jpg?cache=20240125052905
#
#                                                               media_pictures_7_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_8.jpg?cache=20240125052905
#
#    media_pictures_7_isVertical  \
# 0                        False
#
#                                                               media_pictures_8_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_9.gif?cache=20240125052905
#
#                                                                media_pictures_8_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_9.jpg?cache=20240125052905
#
#                                                               media_pictures_8_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_9.jpg?cache=20240125052905
#
#    media_pictures_8_isVertical  \
# 0                        False
#
#                                                               media_pictures_9_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_0.gif?cache=20240125052905
#
#                                                                media_pictures_9_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_0.jpg?cache=20240125052905
#
#                                                               media_pictures_9_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_0.jpg?cache=20240125052905
#
#    media_pictures_9_isVertical  \
# 0                        False
#
#                                                              media_pictures_10_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_A.gif?cache=20240125052906
#
#                                                               media_pictures_10_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_A.jpg?cache=20240125052906
#
#                                                              media_pictures_10_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_A.jpg?cache=20240125052906
#
#    media_pictures_10_isVertical  \
# 0                         False
#
#                                                              media_pictures_11_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_B.gif?cache=20240125052906
#
#                                                               media_pictures_11_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_B.jpg?cache=20240125052906
#
#                                                              media_pictures_11_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_B.jpg?cache=20240125052906
#
#    media_pictures_11_isVertical  \
# 0                         False
#
#                                                              media_pictures_12_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_C.gif?cache=20240125052906
#
#                                                               media_pictures_12_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_C.jpg?cache=20240125052906
#
#                                                              media_pictures_12_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_C.jpg?cache=20240125052906
#
#    media_pictures_12_isVertical  \
# 0                         False
#
#                                                              media_pictures_13_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_D.gif?cache=20240125052906
#
#                                                               media_pictures_13_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_D.jpg?cache=20240125052906
#
#                                                              media_pictures_13_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_D.jpg?cache=20240125052906
#
#    media_pictures_13_isVertical  \
# 0                         False
#
#                                                              media_pictures_14_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_E.gif?cache=20240125052906
#
#                                                               media_pictures_14_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_E.jpg?cache=20240125052906
#
#                                                              media_pictures_14_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_E.jpg?cache=20240125052906
#
#    media_pictures_14_isVertical  \
# 0                         False
#
#                                                              media_pictures_15_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_F.gif?cache=20240125052906
#
#                                                               media_pictures_15_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_F.jpg?cache=20240125052906
#
#                                                              media_pictures_15_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_F.jpg?cache=20240125052906
#
#    media_pictures_15_isVertical  \
# 0                         False
#
#                                                              media_pictures_16_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_G.gif?cache=20240125052906
#
#                                                               media_pictures_16_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_G.jpg?cache=20240125052906
#
#                                                              media_pictures_16_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_G.jpg?cache=20240125052906
#
#    media_pictures_16_isVertical  \
# 0                         False
#
#                                                              media_pictures_17_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_H.gif?cache=20240125052906
#
#                                                               media_pictures_17_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_H.jpg?cache=20240125052906
#
#                                                              media_pictures_17_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_H.jpg?cache=20240125052906
#
#    media_pictures_17_isVertical  \
# 0                         False
#
#                                                              media_pictures_18_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_I.gif?cache=20240125052906
#
#                                                               media_pictures_18_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_I.jpg?cache=20240125052906
#
#                                                              media_pictures_18_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_I.jpg?cache=20240125052906
#
#    media_pictures_18_isVertical  \
# 0                         False
#
#                                                              media_pictures_19_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_J.gif?cache=20240125052906
#
#                                                               media_pictures_19_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_J.jpg?cache=20240125052906
#
#                                                              media_pictures_19_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_J.jpg?cache=20240125052906
#
#    media_pictures_19_isVertical  \
# 0                         False
#
#                                                              media_pictures_20_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_K.gif?cache=20240125052906
#
#                                                               media_pictures_20_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_K.jpg?cache=20240125052906
#
#                                                              media_pictures_20_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_K.jpg?cache=20240125052906
#
#    media_pictures_20_isVertical  \
# 0                         False
#
#                                                              media_pictures_21_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_L.gif?cache=20240125052906
#
#                                                               media_pictures_21_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_L.jpg?cache=20240125052906
#
#                                                              media_pictures_21_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_L.jpg?cache=20240125052906
#
#    media_pictures_21_isVertical  \
# 0                         False
#
#                                                              media_pictures_22_smallUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_M.gif?cache=20240125052906
#
#                                                               media_pictures_22_mediumUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/M_11094262_M.jpg?cache=20240125052906
#
#                                                              media_pictures_22_largeUrl  \
# 0  https://static.immoweb.be/photos/1/1/0/9/4/2/6/2/11094262_M.jpg?cache=20240125052906
#
#    media_pictures_22_isVertical  media_virtualTourUrl  media_floorPlans  \
# 0                         False                   NaN               NaN
#
#    media_specifications  media_virtualExperienceUrl property_type  \
# 0                   NaN                         NaN         HOUSE
#
#        property_subtype  \
# 0  EXCEPTIONAL_PROPERTY
#
#                                             property_title  \
# 0  Prestige property for sale located in a Park over 16 HA
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       property_description  \
# 0  Prestige property located in a Park over 16 HA.  Exceptional manor house, steeped in history and full of potential.  Close to the main roads, near to Louvain-la-Neuve and all amenities (train station, university, E411, Esplanade), we are honoured to be able to present you the "Manoir de Profondval", built in the 60s, set in an estate of more than 16 ha of parkland, meadows and forests, facing south-west and not overlooked.  The property has a built area of more than 750 m², divided as follows:  On the ground floor, a majestic marble entrance gallery leads to the cloakroom (and toilet), the lounge with access to the terrace overlooking the entire estate, a dining room, a study (or bedroom) with a bathroom, a kitchen/office with service hall,a laundry room, a breakfast room.  The first floor comprises a night hall, a master suite with lounge, bathroom, dressing room and terrace the right wing of the first floor contains a further suite with its own bathroom and dressing room, 4 further bedrooms and 2 bathrooms complete the picture.  The property has a swimming pool with pool-house and a tennis court.   It is served by a beautiful long private driveway with automatic security gate, exterior lighting, 3 garages and numerous parking spaces.  A safe room and a lift complete this exceptional property full of surprises.  PEB E (359kWh/m²).  Contact us now to visit +32 (0)477 42 43 04.
#
#    property_name  property_isHolidayProperty  property_bedroomCount  \
# 0            NaN                         NaN                      6
#
#    property_bedrooms_0_surface  property_bedrooms_1_surface  \
# 0                           25                           25
#
#    property_bedrooms_2_surface  property_bedrooms_3_surface  \
# 0                           18                           18
#
#    property_bedrooms_4_surface  property_bathroomCount  \
# 0                           16                       4
#
#   property_location_country property_location_region  \
# 0                   Belgium                 Wallonie
#
#   property_location_province property_location_district  \
# 0            Walloon Brabant                   Nivelles
#
#    property_location_locality  property_location_postalCode  \
# 0  Ottignies-Louvain-la-Neuve                          1348
#
#    property_location_street  property_location_number  property_location_box  \
# 0                       NaN                       NaN                    NaN
#
#    property_location_propertyName  property_location_floor  \
# 0                             NaN                      NaN
#
#    property_location_latitude  property_location_longitude  \
# 0                         NaN                          NaN
#
#    property_location_distance  property_location_approximated  \
# 0                         NaN                             NaN
#
#   property_location_regionCode  property_location_type  \
# 0                     WALLONIE                     NaN
#
#    property_location_hasSeaView  property_location_pointsOfInterest  \
# 0                           NaN                                 NaN
#
#    property_location_placeName  property_netHabitableSurface  \
# 0                          NaN                           750
#
#    property_roomCount  property_monthlyCosts  property_attic  \
# 0                   7                    NaN             NaN
#
#    property_hasAttic  property_basement_surface  property_hasBasement  \
# 0                NaN                        NaN                  True
#
#    property_hasDressingRoom  property_diningRoom  property_hasDiningRoom  \
# 0                       NaN                  NaN                     NaN
#
#    property_building_annexCount property_building_condition  \
# 0                           NaN               TO_BE_DONE_UP
#
#    property_building_constructionYear  property_building_facadeCount  \
# 0                                1961                              4
#
#    property_building_floorCount  property_building_streetFacadeWidth  \
# 0                             1                                  NaN
#
#    property_propertyCertificates_builtPlanStatus  \
# 0                                            NaN
#
#    property_propertyCertificates_globalInsulationLevel  \
# 0                                                  NaN
#
#    property_propertyCertificates_oilTankCertificateStatus  \
# 0                                                     NaN
#
#    property_propertyCertificates_primaryEnergyConsumptionLevel  \
# 0                                                          NaN
#
#    property_hasCaretakerOrConcierge  property_hasDisabledAccess  \
# 0                              True                       False
#
#    property_hasLift  property_constructionPermit_constructionType  \
# 0             False                                           NaN
#
#   property_constructionPermit_floodZoneType  \
# 0                            NON_FLOOD_ZONE
#
#    property_constructionPermit_isObtained  \
# 0                                     NaN
#
#    property_constructionPermit_hasObligationToConstruct  \
# 0                                                   NaN
#
#    property_constructionPermit_hasPlotDivisionAuthorization  \
# 0                                                       NaN
#
#    property_constructionPermit_hasPossiblePriorityPurchaseRight  \
# 0                                                           NaN
#
#    property_constructionPermit_isBreachingUrbanPlanningRegulation  \
# 0                                                             NaN
#
#    property_constructionPermit_floodZoneIconUrl  \
# 0                                           NaN
#
#    property_constructionPermit_totalBuildableGroundFloorSurface  \
# 0                                                           758
#
#    property_constructionPermit_urbanPlanningInformation  \
# 0                                                   NaN
#
#    property_constructionPermit_pScore  property_constructionPermit_gScore  \
# 0                                 NaN                                 NaN
#
#    property_energy  property_kitchen_surface property_kitchen_type  \
# 0              NaN                        29         SEMI_EQUIPPED
#
#    property_kitchen_hasOven  property_kitchen_hasMicroWaveOven  \
# 0                       NaN                                NaN
#
#    property_kitchen_hasDishwasher  property_kitchen_hasWashingMachine  \
# 0                             NaN                                 NaN
#
#    property_kitchen_hasFridge  property_kitchen_hasFreezer  \
# 0                         NaN                          NaN
#
#    property_kitchen_hasSteamOven  \
# 0                            NaN
#
#    property_land_hasGasWaterElectricityConnection  \
# 0                                             NaN
#
#    property_land_hasPlotToRear  property_land_isFacingStreet  \
# 0                          NaN                           NaN
#
#    property_land_isFlat  property_land_isWooded  property_land_landWidth  \
# 0                   NaN                     NaN                       24
#
#    property_land_latestUseDesignation  property_land_rearLand  \
# 0                                 NaN                     NaN
#
#    property_land_sewerConnection  property_land_surface  property_laundryRoom  \
# 0                            NaN                 160737                   NaN
#
#    property_hasLaundryRoom  property_livingRoom_surface  \
# 0                      NaN                           40
#
#    property_hasLivingRoom  property_isFirstOccupation  property_hasBalcony  \
# 0                    True                         NaN                  NaN
#
#    property_hasBarbecue  property_hasGarden  property_gardenSurface  \
# 0                   NaN                 NaN                     NaN
#
#    property_gardenOrientation  property_parkingCountIndoor  \
# 0                         NaN                          NaN
#
#    property_parkingCountOutdoor  property_parkingCountClosedBox  \
# 0                             6                             NaN
#
#    property_hasAirConditioning  property_hasArmoredDoor  \
# 0                          NaN                      NaN
#
#    property_hasVisiophone  property_hasSecureAccessAlarm  property_hasCableTV  \
# 0                    True                           True                  NaN
#
#    property_hasDoorPhone  property_hasInternet  property_showerRoomCount  \
# 0                   True                   NaN                         4
#
#    property_specificities_internalFixturesAndFittings  \
# 0                                                 NaN
#
#    property_specificities_miscellaneousFixturesAndFittings  \
# 0                                                      NaN
#
#    property_specificities_totalFloorSurface  \
# 0                                       NaN
#
#    property_specificities_accessDoorCount  \
# 0                                     NaN
#
#    property_specificities_sectionalDoorCount  \
# 0                                        NaN
#
#    property_specificities_slidingDoorCount  \
# 0                                      NaN
#
#    property_specificities_loadingBayCount  \
# 0                                     NaN
#
#    property_specificities_coveredBaysCount  \
# 0                                      NaN
#
#    property_specificities_loadingBayWithLiftingDeviceCount  \
# 0                                                      NaN
#
#    property_specificities_ceilingHeight  \
# 0                                   NaN
#
#    property_specificities_maxAvailableHeight  \
# 0                                        NaN
#
#    property_specificities_minAvailableHeight  \
# 0                                        NaN
#
#    property_specificities_showroomSurface  \
# 0                                     NaN
#
#    property_specificities_hasReceptionDesk  \
# 0                                      NaN
#
#    property_specificities_shopWindowWidth  property_specificities_hasGoodwill  \
# 0                                     NaN                                 NaN
#
#    property_specificities_goodwillPrice  property_specificities_hasOffice  \
# 0                                   NaN                              True
#
#    property_specificities_office_surface  property_specificities_hasWorkspace  \
# 0                                     18                                  NaN
#
#    property_specificities_workspace  property_toiletCount  \
# 0                               NaN                     7
#
#    property_hasFitnessRoom  property_hasTennisCourt  property_hasSwimmingPool  \
# 0                      NaN                      NaN                      True
#
#    property_hasSauna  property_hasJacuzzi  property_hasHammam  \
# 0                NaN                  NaN                 NaN
#
#    property_bedroomSurface  \
# 0                      NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         property_alternativeDescriptions_fr  \
# 0  Propriété de Prestige dans un Parc de 16Ha.  A proximité des axes routiers et de toutes les facilités (gare, université, E411), laissez-vous charmer par le « Manoir de Profondval », plus de 750 m², logé dans un domaine de 16 ha (parc, prairies et forêts), orienté SO et sans aucun vis-à-vis.  Au rez-de-chaussée, une majestueuse galerie d'entrée en marbre conduit au vestiaire (et toilettes), au salon avec accès à la terrasse, qui surplombe tout le domaine, à une salle à manger, à un bureau (ou chambre) avec SDB attenante, à une cuisine/office avec hall de service, une buanderie et 3 garages.  Le 1er étage comprend un hall de nuit, une suite parentale avec salon, salle de bains, dressing et terrasse  l'aile droite du premier étage contient une suite supplémentaire avec sa propre salle de bains et son dressing, et 4 autres chambres avec 2 SDB.  La propriété est pourvue d'une piscine avec poolhouse et d'un terrain de tennis.   Elle est desservie par une imposante allée privative, avec portail sécurisé et automatique, un éclairage extérieur, comprend encore 3 garages et de nombreux emplacements de parkings, une salle des coffres et un ascenseur. PEB E (359kWh/m²).  Contactez-nous sans tarder +32 (0)477 42 43 04
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        property_alternativeDescriptions_nl  \
# 0  Prestigieus herenhuis in meer dan 16Ha parklandschap.  Uitzonderlijk herenhuis, rijk aan geschiedenis en vol potentieel, alleen te koop voor prestigieuze kopers. Dicht bij de belangrijkste wegen, vlak bij Louvain-la-Neuve en alle voorzieningen (treinstation, universiteit, E411, Esplanade), zijn we vereerd u het "Manoir de Profondval" te kunnen presenteren, gebouwd in de jaren '60, gelegen in een domein van meer dan 16 ha park, weiden en bossen, op het zuidwesten en zonder inkijk. Het pand heeft een bebouwde oppervlakte van meer dan 750 m², als volgt verdeeld: Op de begane grond leidt een majestueuze marmeren entreegalerij naar de garderobe (en toilet), de zitkamer met toegang tot het terras met uitzicht over het hele landgoed, een eetkamer,een studeerkamer (of slaapkamer) met eigen badkamer, een keuken/kantoor met servicehal, een wasruimte en een ontbijtruimte. De eerste verdieping bestaat uit een nachthal, een master suite met zitkamer, badkamer, kleedkamer en terras de rechtervleugel van de eerste verdieping bevat nog een suite met eigen badkamer en kleedkamer, nog 4 slaapkamers en 2 badkamers maken het plaatje compleet. Het eigendom heeft een zwembad met pool-house en een tennisbaan.   Er is een prachtige lange oprijlaan met automatische beveiligingspoort, buitenverlichting, 3 garages en talloze parkeerplaatsen.  Een kluisruimte en een lift completeren dit uitzonderlijke object vol verrassingen.  EPC E (359kWh/m²). Contacteer ons nu om te bezoeken +32 (0)477 42 43 04.
#
#    property_habitableUnitCount  property_fireplaceCount  \
# 0                          NaN                      NaN
#
#    property_fireplaceExists  property_hasTerrace  property_terraceSurface  \
# 0                     False                 True                      125
#
#    property_terraceOrientation      publication_creationDate  \
# 0                          NaN  2024-01-25T05:24:32.000+0000
#
#      publication_expirationDate  publication_publisherId  \
# 0  2024-02-29T22:59:59.000+0000                      NaN
#
#   publication_visualisationOption publication_lastModificationDate  \
# 0                              XL     2024-02-21T09:29:33.107+0000
#
#   transaction_type transaction_subtype transaction_availabilityPeriodType  \
# 0         FOR_SALE         BUY_REGULAR                        IMMEDIATELY
#
#    transaction_availabilityDate  transaction_certificates_carbonEmission  \
# 0  2024-04-01T00:00:00.000+0000                                       89
#
#    transaction_certificates_hasElectricalInstallationComplianceCertificate  \
# 0                                                                      NaN
#
#    transaction_certificates_primaryEnergyConsumptionPerSqm  \
# 0                                                      359
#
#    transaction_certificates_primaryEnergyConsumptionYearly  \
# 0                                                   272394
#
#    transaction_certificates_epcDescription  \
# 0                                      NaN
#
#    transaction_certificates_epcReference transaction_certificates_epcScore  \
# 0                         20200612009940                                 E
#
#                 transaction_certificates_epcUrl  transaction_rental  \
# 0  https://static.immoweb.be/pics/peb/peb_e.png                 NaN
#
#    transaction_sale_price  transaction_sale_isSubjectToVat  \
# 0                 3790000                            False
#
#    transaction_sale_cadastralIncome  transaction_sale_publicSale  \
# 0                                 0                          NaN
#
#    transaction_sale_pricePerSqm  transaction_sale_oldPrice  \
# 0                           NaN                        NaN
#
#    transaction_sale_lifeAnnuity  transaction_sale_hasStartingPrice  \
# 0                           NaN                              False
#
#    transaction_sale_isFurnished  transaction_sale_homeToBuild  \
# 0                         False                           NaN
#
#    transaction_sale_newBuildsTotalPrice  transaction_sale_newBuildsVAT  \
# 0                                   NaN                            NaN
#
#    transaction_sale_newBuildsLandPrice  transaction_sale_newBuildsLandTaxes  \
# 0                                  NaN                                  NaN
#
#    transaction_investor_isInvestmentProperty  \
# 0                                      False
#
#    transaction_investor_currentMonthlyRentalIncome  \
# 0                                              NaN
#
#    transaction_investor_currentReturnOnInvestment  \
# 0                                             NaN
#
#    transaction_investor_expectedMonthlyRentalIncome  \
# 0                                               NaN
#
#    transaction_investor_expectedMonthlyRentalIncomeDescription  \
# 0                                                          NaN
#
#    transaction_investor_expectedReturnOnInvestment  \
# 0                                              NaN
#
#    transaction_investor_habitableUnitCount  \
# 0                                      NaN
#
#    transaction_investor_occupancyRate  priceType        price_type  \
# 0                                 NaN        NaN  residential_sale
#
#    price_mainValue  price_alternativeValue  price_additionalValue  \
# 0          3790000                     NaN                    NaN
#
#    price_oldValue  price_minRangeValue  price_maxRangeValue  \
# 0             NaN                  NaN                  NaN
#
#   price_mainDisplayPrice                      price_HTMLDisplayPrice  \
# 0             3,790,000  <span aria-hidden="true">3,790,000</span>
#
#    price_alternativeDisplayPrice  price_oldDisplayPrice  \
# 0                            NaN                    NaN
#
#   price_shortDisplayPrice price_accessibilityPrice price_label  price_date  \
# 0                   3.8M                 3790000       Price         NaN
#
#   price_language  externalReference  isBookmarked  \
# 0             en            5825169         False
#
#    hasSectionsArray_hasGeneralSection  hasSectionsArray_hasInteriorSection  \
# 0                                True                                 True
#
#    hasSectionsArray_hasExteriorSection  hasSectionsArray_hasFacilitiesSection  \
# 0                                 True                                   True
#
#    hasSectionsArray_hasEnergySection  hasSectionsArray_hasPlanningSection  \
# 0                               True                                 True
#
#    hasSectionsArray_hasFinancialSection  \
# 0                                  True
#
#    hasSectionsArray_hasPublicSaleSection  displayFlags_main  \
# 0                                  False                NaN
#
#    displayFlags_percentSold  statistics_bookmarkCount  statistics_viewCount  \
# 0                       NaN                        30                  2098
#
#    statistics_alertPrice  statistics_creationDate  statistics_description  \
# 0                    NaN                      NaN                     NaN
#
#    statistics_isAlertEmailSet  statistics_rating  \
# 0                         NaN                NaN
#
#    statistics_wasOwnerContacted  statistics_wasPropertyVisited
# 0                           NaN                            NaN
